# %%
# seaborn is also comes in mapplot
import pandas as pd

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.countplot(data =df,x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
plt .figure(figsize=(5,3))
house = ["red","yellow","green","blue"]
frequency = [20,40,5,50]
plt.bar(house,frequency)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.countplot(data=df,x="sex",hue="smoker") #hue divide the data
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=df,x="day",hue="smoker") #(hue="day") shows all the weeks data
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ## barplot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby("day")["size"].sum()
# Out:
# day
# Fri      40
# Sat     219
# Sun     216
# Thur    152
# Name: size, dtype: int64

# %%
df.groupby("day")["size"].sum().index #shows in list
# Out:
# Index(['Fri', 'Sat', 'Sun', 'Thur'], dtype='object', name='day')

# %%
df.groupby("day")["size"].sum().values
# Out:
# array([ 40, 219, 216, 152])

# %%
pd.DataFrame(df.groupby("day")["size"].mean()) #max()
# Out:
#           size
# day
# Fri   2.105263
# Sat   2.517241
# Sun   2.842105
# Thur  2.451613

# %%
sns.barplot(data=df,x="day",y="size",errorbar=None,hue="smoker") #errorbar removes the error bar in barplot #if max is used [estimator = "max"] is used
# Out:
# <Axes: xlabel='day', ylabel='size'>

# %%
import pandas as pd

# %%
gap=pd.read_csv("gap_data.csv")
gap
# Out:
#     country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 0    Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 1    Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 2    Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 3    Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 4    Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 5    Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 6    Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 7    Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 8    Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 9    Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 10   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 11   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=gap,x="year",y="lifeExp",hue="country",style="continent",markers=["o","d","s"]) #style shows the pattern of data ,markers shows the design type in the fixed data
plt.xticks(year)
plt.show()

# %%
year=list(set(gap["year"].tolist()))
year
# Out:
# [1952, 1987, 1957, 1992, 1962, 1997, 1967, 2002, 1972, 2007, 1977, 1982]

# %% [markdown]
# ## heatmap

# %%
gaps=pd.read_csv("gap.csv")
gaps
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#piovet table , it makes long table to flat

# %%
pd.pivot(gaps,index="country",columns="year",values="lifeExp") # values shows what we want, columns shows what is to be shown and on
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
temp = pd.pivot(gaps,index="country",columns="year",values=["lifeExp","pop"])

# %%
temp
# Out:
#                    lifeExp                                                  \
# year                  1952    1957    1962    1967    1972    1977    1982
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
cols=[f"{item[0]}_{item[1]}"for item in list(temp.columns)]

# %%
temp.columns=cols

# %%
temp
# Out:
#                     lifeExp_1952  lifeExp_1957  lifeExp_1962  lifeExp_1967  \
# country
# Afghanistan               28.801        30.332        31.997        34.020
# Albania                   55.230        59.280        64.820        66.220
# Algeria                   43.077        45.685        48.303        51.407
# Angola                    30.015        31.999        34.000        35.985
# Argentina                 62.485        64.399        65.142        65.634
# ...                          ...           ...           ...           ...
# Vietnam                   40.412        42.887        45.363        47.838
# West Bank and Gaza        43.160        45.671        48.127        51.631
# Yemen, Rep.               32.548        33.970        35.180        36.984
# Zambia                    42.038        44.077        46.023        47.768
# Zimbabwe                  48.451        50.469        52.358        53.995
#
# ...

# %%
pivot=pd.pivot(gaps,index="country",columns="year",values="lifeExp").sample(10) #sample takes the random value 
pivot
# Out:
# year          1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Albania     55.230  59.280  64.820  66.220  67.690  68.930  70.420  72.000
# Japan       63.030  65.500  68.730  71.430  73.420  75.380  77.110  78.670
# France      67.410  68.930  70.510  71.550  72.380  73.830  74.890  76.340
# Guatemala   42.023  44.142  46.954  50.016  53.738  56.029  58.137  60.782
# Kenya       42.270  44.686  47.949  50.654  53.559  56.155  58.766  59.339
# Mozambique  31.286  33.779  36.161  38.113  40.328  42.495  42.795  42.861
# Rwanda      40.000  41.500  43.000  44.100  44.600  45.000  46.218  44.020
# Nepal       36.157  37.686  39.393  41.472  43.971  46.748  49.594  52.537
# Uganda      39.978  42.571  45.344  48.051  51.016  50.350  49.849  51.509
# Austria     66.800  67.480  69.540  70.140  70.630  72.170  73.180  74.940
#
# year          1992    1997    2002    2007
# country
# Albania     71.581  72.950  75.651  76.423
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(pivot,annot=True,cmap="summer",cbar=False,linewidths=1,linecolor="black") #annot shows with integer value as data , cmap gives the color changes
# Out:
# <Axes: xlabel='year', ylabel='country'>
